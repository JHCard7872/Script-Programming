# %%
def add(a,b):
    return a+b

print(add(1,2))
print(add('abc', 'def'))
print(add([1, 2, 3], [4, 5, 6]))
# Out:
# 3
# abcdef
# [1, 2, 3, 4, 5, 6]

# %%
a= 10 ** 1000

# %%
print(a)
# Out:
# ...

# %% [markdown]
# - 고수준의 내장(built-in) 자료형 제공

# %%
a=[12, 'abcde', [3,4,5]] #리스트
a.append('add') #append가 뒤에 붙이는거
print(a)
# Out:
# [12, 'abcde', [3, 4, 5], 'add']

# %% [markdown]
# - 메모리 자동 관리
# - 쉬운 유지 보수
# - 많은 수의 라이브러리 제공
# - 짧아지는 코드
# - 높은 확장성
# - pypi.org 참고 >> 파이썬 프로젝트?(많은 수의 라이브러리)

# %% [markdown]
# # 파이썬의 장점
#
# - 들여쓰기를 철저하게 지키도록 설계하였다.
# - 이는 가독성을 높혀준다.
# - 괄호를 넣지 않기 때문에 깔끔하다.
# - 재사용하기 쉽다.
# - 코드 분석이 쉬워 편하게 작업할 수 있다.
