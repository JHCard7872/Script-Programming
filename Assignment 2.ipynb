# %% [markdown]
# # <center> Assignment 2</center>
#
# ### 2020136082 오준혁

# %% [markdown]
# ### 1. 다음 6 개의 Expression에 대해 Evaluation 결과 값을 출력하고, 해당 결과가 나온 이유에 대해 설명하시오
# - 1 and 2 and 3 and 4
# - 1 or 2 or 3 or 4
# - 1 and 2 or 3 and 4
# - (1 and 2) or (3 and 4)
# - 1 or 2 and 3 or 4
# - (1 or 2) and (3 or 4)

# %%
print(1 and 2 and 3 and 4)
# Out:
# 4

# %% [markdown]
# and 연산은 a and b라 하면, 참일 경우 b의 값 리턴, 거짓일 경우 거짓인 값을 리턴해주고, or 연산은 a or b라 하면, 참일 경우 a값 리턴, 거짓일 경우 거짓인 값을 리턴해준다. 이를 생각해보면 0이 아닌 수들은 참으로 생각을 하기 때문에 뒤의 값을 리턴해주어 4의 결과값이 나오게 된다.

# %%
print(1 or 2 or 3 or 4)
# Out:
# 1

# %% [markdown]
# 위의 내용을 참고하면 or는 전부 1 or 2에서 1리턴(0이 아니므로 참) 1 or 3에서 1리턴, 1 or 4에서 1리턴을 해주므로 1의 결과값이 나오게 된다.

# %%
print(1 and 2 or 3 and 4)
# Out:
# 2

# %% [markdown]
# and 와 or는 우선수위가 서로 다르다. and 연산의 우선순위가 먼저이므로 1 and 2 와 3 and 4를 계산을 한 뒤, or를 계산해준다. 그러면 1 and 2 에서 2, 3 and 4에서 4, 2 or 4 에서 2가 나온다.

# %%
print((1 and 2) or (3 and 4))
# Out:
# 2

# %% [markdown]
# 결과값은 위와 같다. 우선순위가 and가 우선이므로 위와 우선순위는 같으므로 결과값도 같다.

# %%
print(1 or 2 and 3 or 4)
# Out:
# 1

# %% [markdown]
# 2 and 3에서 3을 반환해주므로 1 or 3 or 4가 되고, 순서대로 하면 1의 값이 나오게 된다.

# %%
print((1 or 2) and (3 or 4))
# Out:
# 3

# %% [markdown]
# 여기는 괄호를 주어 or가 먼저 계산하게끔 하여 위의 값과 다르게 나온다. 1 or 2에서 1, 3 or 4에서 3이 나오고, 1 and 3에서 3이 나오므로 결과값은 3이 나오게 된다.
#
# -----

# %% [markdown]
# ### 2. 경로에 해당하는 문자열 1개를 입력 받아 그 안에 디렉토리 경로명과 파일명을 분리하여 리스트로 반환하는 함수 div_path(s)를 작성하시오.
# - 인자로 전달하는 문자열은 경로만 들어간다고 가정한다.
# - 각 디렉토리와 파일을 구분하는 문자는 '/'로 가정한다.
# - 반환하는 리스트의 첫번째 원소는 디렉토리이고 두번째 원소는 파일명이다.
# - 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#     - div_path('/usr/local/bin/python')
#         - ['/usr/local/bin', 'python']
#     - div_path('/home/chulsoo/test.txt')
#         - ['/home/chulsoo', 'test.txt']
# - [참고] 리스트(l) 내에 새로운 정수값 (예를 들어 10)을 넣는 방법은 l.append(10) 이다.

# %%
def div_path(s):
    count = 0
    for ch in range(len(s)): # 매개변수의 s의 길이만큼 반복
        if(s[len(s)-ch-1]=='/'): # s배열의 거꾸로 시작해서 '/' 확인시 종료
            break
        count = count+1 # '/'를 확인을 못하면 count 증가
    dir = s[0:len(s)-count-1] # dir의 값에 s[0] 부터 s[s의 길이 - count]값 전체 저장
    file = s[len(s)-count:len(s)] # 거꾸로 생각해서 '/'부터 끝까지 저장
    print("['" + dir + "', '" + file + "']") # 출력
div_path('/usr/local/bin/python')
div_path('/home/chulsoo/test.txt')
# Out:
# ['/usr/local/bin', 'python']
# ['/home/chulsoo', 'test.txt']

# %% [markdown]
# 문자열을 받으면 그 값을 거꾸로 확인하여 '/'값이 나올때까지 count변수를 증가 시켜준다. 그러면 count값이 파일명의 길이가 되므로 s[0:문자열의 길이 - 파일명의 길이 - 1]이 디렉토리 경로명이 되고 s[문자열의 길이 - 파일명의 길이 : 문자열의 길이]가 파일명이 된다. 이를 출력하면 결과값이 나오게 된다.
#
# -----

# %% [markdown]
# ### 3. 두 개의 리스트를 인자로 받아서 그 두 개의 리스트에 대한 '합집합'을 반환하는 함수 list_union(lista, listb)를 작성하시오.
# - 집합 자료형 set은 사용하지 않는다.
# - 인자로 전달하는 리스트 2 개에는 정수값만 들어간다고 가정하자.
# - 함수 내에서 새로운 리스트를 만들어 그 리스트 내에 인자로 받은 두 리스트의 모든 원소를 넣어 반환한다.
# - 반환하는 리스트에는 절대로 중복된 원소가 들어 있으면 안된다 (집합의 조건).
# - 반환하는 리스트는 정렬이 되어 있어야 한다.
# - 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#     - list_union([1, 2, 3], [1, 2, 4])
#         - [1, 2, 3, 4]
#     - list_union([-10, -5, 0, -1], [100, 9, 0, 9])
#         - [-10, -5, -1, 0, 9, 100]
#     - list_union([0, 1, 2], [0, 1, 2])
#         - [0, 1, 2]
# - [참고] 리스트(l) 내에 새로운 정수값 (예를 들어 10)을 넣는 방법은 l.append(10) 이다.
# - [참고] 임의의 정수값 (x)이 리스트 (l) 내에 존재하는지 판단하는 방법은 x in l 이다.

# %%
def list_union(lista, listb):
    list = lista + listb # 리스트에 두 개의 리스트를 저장
    list.sort() # 정렬
    count = 0
    for ch in range(len(list)): # 길이만큼 반복
        if(count==len(list)-1): # count값은 중복되는것이 있을때마다 -1, 반복 할떄마다 +1을 해줌
            break
        if(list[count] == list[count+1]): #중복되는 값이 있을때 삭제 및 count -1
            list.remove(list[count])
            count = count - 1
        count = count+1
    return list # 반환
    
print(list_union([1, 2, 3], [1, 2, 4]))
print(list_union([-10, -5, 0, -1], [100, 9, 0, 9]))
print(list_union([0, 1, 2], [0, 1, 2]))
# Out:
# [1, 2, 3, 4]
# [-10, -5, -1, 0, 9, 100]
# [0, 1, 2]

# %% [markdown]
# 전체적으로 하나의 리스트 안에 2개의 리스트를 넣어주고 정렬을 한다. 중복되는 값을 찾기 위해 반복문을 실행하고 중복될 경우 그 값을 삭제한다. 삭제할 경우 리스트들이 삭제 된 자리를 메꾸는데 그것을 count를 선언해주어 해결해주었다. 삭제할때마다 count값을 -1해주고, 검사를 진행할때 마다 +1을 해준다. 리스트의 길이만큼 진행을 해주어야 하기 때문에 길이에 닿으면 break를 해주어 함수를 종료해주었다.
#
# -----

# %% [markdown]
# ### 4. 두 개의 리스트를 인자로 받아서 그 두 개의 리스트에 대한 '교집합'을 반환하는 함수 list_intersection(lista, listb)와 '차집합'을 반환하는 함수 list_difference(lista, listb)를 작성하시오.
# - 모든 가정과 조건은 3번 문제와 동일하다.

# %%
def list_intersection(lista, listb):
    list = []
    for ch in range(len(lista)): # lista만큼 반복
        for ch2 in range(len(listb)): #listb만큼 반복
            if(lista[ch] in listb ): #lista의 ch번째의 수가 listb에 있을경우
                if(lista[ch] in list): # 이미 list에 존재하면 continue
                    continue 
                else: # 해당할 경우 list에 저장
                    list.append(lista[ch])
    return list
print(list_intersection([1, 2, 3], [1, 2, 4]))
print(list_intersection([-10, -5, 0, -1], [100, 9, 0, 9]))
print(list_intersection([0, 1, 2], [0, 1, 2]))

def list_difference(lista, listb):
    list = []
                            
    for ch3 in range(len(listb)):
        if(listb[ch3] in lista ): # 리스트에 있을경우 continue
            continue
        else: #상대 리스트에도 없고 출력해줄 list에도 없으면 저장 있으면 continue
            if(listb[ch3] in list):
                continue
            list.append(listb[ch3])
                        
    for ch in range(len(lista)): # 나머지 리스트도 똑같이 진행
        if(lista[ch] in listb ):
            continue
        else:
            if(lista[ch] in list):
                continue
            list.append(lista[ch])
    return list
print(list_difference([1, 2, 3], [1, 2, 4]))
print(list_difference([-10, -5, 0, -1], [100, 9, 0, 9]))
print(list_difference([0, 1, 2], [0, 1, 2]))
# Out:
# [1, 2]
# [0]
# [0, 1, 2]
# [4, 3]
# [100, 9, -10, -5, -1]
# []

# %% [markdown]
# intersection함수는 하나의 리스트를 선택하여 상대 리스와 반복문으로 비교하여 있을경우 새로운 list에 저장해준다.
# difference함수는 intersecion에서 중복되는 것을 확인하면 continue, 중복되지 않으면 list에 저장, 만약 이미 list에 있는 수면 continue를 해주어 list에 저장을 해주고 출력해주었다.
#
# -----

# %% [markdown]
# ### 5. 두 개의 양의 정수를 인자로 받아서 해당 범위안에 있는 소수(prime number)의 리스트를 출력하는 함수 print_primenumber(a, b)를 작성하시오.
# - 이미 구현된 모듈이나 라이브러리는 사용하지 않는다.
# - 함수의 반환(return)은 없으며 함수 내의 끝에서 .format()을 사용하여 다음과 같이 출력한다.
#     - print_primenumber(2, 10)
#         - 2 이상 10 이하 정수 중 소수 리스트: [2, 3, 5, 7]

# %%
def print_primenumber(a, b):
    list = []
    for ch in range(a, b+1): # a부터 b까지 판단해야 하므로
        check = True #소수 판단 변수
        for prime in range(2, ch):
            if(ch % prime == 0): # b-1까지의 값으로 나누어 지면 false체크
                check = False
                break
        if(check): # check가 true이면 소수
            list.append(ch)
    print('{} 이상 {} 이하 정수 중 소수 리스트: {}'.format(a, b, list)) # format사용
print_primenumber(2,10)
# Out:
# 2 이상 10 이하 정수 중 소수 리스트: [2, 3, 5, 7]

# %% [markdown]
# a부터 반복을 시작하여 b까지 검사를 해야하므로 a, b+1로 range를 설정해주어 반복을 실행해주었고, 2부터 ch까지 나누어지면 check를 false로 변환 및 break해주어 list에 저장해준다. 출력은 .format을 이용하여 예시대로 출력시켜주었다.
#
# -----

# %% [markdown]
# ### [Incremental Project 문제]

# %% [markdown]
# ### 웹 URL로 지정된 웹페이지를 문자열로 가져와 1) 모든 HTML 태그를 제외한 순수 텍스트 문자열만을 걸러내고, 2) 그 순수 텍스트 문자열 안에 존재하는 단어가 총 몇개인지 출력하는 프로그램을 작성하시오.

# %%
import requests

req = requests.get('http://link.koreatech.ac.kr/lecture/2021/script_programming')

source = req.text

# %%
check = True
checkCode = True
index = 0
s = ''
for ch in source:
    if(ch == '<'):
        check = False
    if(source[index:index+7] == '<style>'):
        checkCode = False
    if(check and checkCode):
        s = s + ch
    if(ch == '>'):
        check = True
    if(source[index:index+8] == '</style>'):
        checkCode = True
    if(index != len(source)-9):
        index = index + 1
list = s.split()
print(len(list))
# Out:
# 901

# %% [markdown]
# 출력할때를 구분해주는 check과 checkCode 부울형을 이용하여 해결하였다. 먼저 check변수는 <>괄호 사이에 있는 문자를 저장하는 것을 막아주고, checkCode변수는 <style> 과 </style> 사이에 있는 문자를 저장하는 것을 막아준다. 내가 가져온 주소는http://link.koreatech.ac.kr/lecture/2021/script_programming 로 학부 link사이트의 스크립트 프로그래밍과목 사이트를 이용하였다. 다른 사이트들은 script등 여러개의 예외가 있을 수 있는데, 내가 가져온 URL은 style(예외처리해야할것) 만 존재하여 이부분만 제거해주었다. 이 부분들은 괄호 기호가 나오면 check를 false를 해주고 문자열 s에 저장해줄때는 check와 checkCode변수 모두 true가 나올때만 저장을 해준다. 그러므로 false를 해주면 s에 저장이 되지 않는다. checkCode도 이를 이용해 주었다. 문자열이 저장된 s에는 엔터나 띄어쓰기로 구분이 잘 되지 않기 때문에 split()함수를 이용하여 리스트로 만들어주었고, 이것을 list에 저장해주어 길이를 반환해주었다. 결과값이 단어의 개수가 될것이고, 아래에는 list에 저장된 단어와 사용한 URL이다.

# %%
print(list)
'''['한국기술교육대학교', 'LINK', '연구실', '위치', 'LINK@KOREATECH', 'About', 'Introduction', 'Location', 'Members', 'Professor', 
'Current', 'Students/Members', 'Alumni', 'Publications', 'Papers', 'Patents', 'Standards', 'Research', 'Research', 'Areas', 'Projects',
'Courses', 'Courses&nbsp;(Since', '2021)', 'Old', 'Courses&nbsp;(Until', '2020)', 'Activity', 'News', 'Invited', 'Talks', 'Lab.', 
'Seminar', 'Zoom', 'Meeting', 'Awards', 'Album', 'About', 'Introduction', 'Location', 'Members', 'Professor', 'Current', 
'Students/Members', 'Alumni', 'Publications', 'Papers', 'Patents', 'Standards', 'Books', 'Research', 'Research', 'Areas', 
'Projects', 'Courses', 'Courses&nbsp;(Since', '2021)', 'Old', 'Courses&nbsp;(Until', '2020)', 'Activity', 'News', 'Invited', 
'Talks', 'Lab.', 'Seminar', 'Awards', 'Album', 'Script', 'Programming', 'Home', 'Course', '2021', 'Fall', 'Script', 'Programming', 
'Script', 'Programming', '(스크립트', '프로그래밍,', 'Fall', 'Semester,', '2021', '–', 'CSE221)', '“Student-professor', 
'relationships', 'are', 'based', 'on', 'trust.', 'Acts,', 'which', 'violate', 'this', 'trust,', 'undermine', 'the', 'educational', 
'process.', 'Your', 'classmates', 'and', 'the', 'professor', 'will', 'not', 'tolerate', 'violations', 'of', 'academic', 'integrity”', 
'1.', 'Course', 'Schedule', '&amp;', 'Lecture', 'Notes', '온라인', '강의', '(E-Learning)', '콘텐츠', '학습', '기간', '및', '출석', 
'인정', '날짜:', 'Click', '온라인', '강의', '(E-Learning)', '콘텐츠', '강의', '자료:', 'Click', 'Zoom', '실시간/오프라인', '강의', 
'Jupyter', 'Notebook', '자료:', 'Click', '#', 'Date', '온라인', '강의', '(E-Learning)', '오프라인/Zoom', '실시간', '강의', 'Notice', 
'01', '08월', '31일(화)', '00.', '수업', '소개', '01.', '파이썬', '기초', '돌아보기', '-', 'I', 'Lecture', 'Note', '#01', '파이썬', 
'설치하기', '콘다', '가상환경', '다루기', '파이썬', '처음', '사용하기', '-', '명령어', '모드:', 'ESC', '-', '위로', '셀추가:', 'a',
'-', '아래로', '셀추가:', 'b', '-', '셀', '지우기:', 'dd', '-', '마크다운', '셀로', '변경:', 'm', '-', '코드', '셀로', '변경:', 'y', 
'파이썬', '패키지', '설치하기', 'Pycharm', '설치', '및', '설정', '02', '09월', '03일(금)/07일(화)', '01.', '파이썬', '시작하기02.', 
'파이썬', '언어의', '기본', '01.', '파이썬', '기초', '돌아보기', '-', 'II', 'Lecture', 'Note', '#01', '파이썬', '내장', '함수', 
'"Set"', '메소드', '정리', '"Dictionary"', '메소드', '정리', '문법', '참고', '자료', '03', '09월', '10일(금)/14일(화)', '03.', 
'수치형', '자료형과', '문자열', '자료형의', '특징', '01.', '파이썬', '기초', '돌아보기', '-', 'III', 'Lecture', 'Note', '#01',
'Homework', '#1', 'Due', 'Date:', '2021년', '09월', '24일,', '23시', '59분', '04', '09월', '17일(금)/21일(화)', '04.', '리스트,',
'튜플,', '사전,', '집합', '자료형의', '특징', '02.', '고급', '문자열', '기능', 'Lecture', 'Note', '#02', '[참고]', 'Asterisks', 
'in', 'Python', '20일~22일:', '추석', '연휴', '05', '09월', '24일(금)/28일(화)', '05.', '리스트,', '튜플,', '사전', '자료형의', 
'활용', '03.', '고급', '리스트', '기능', '-', 'I', 'Lecture', 'Note', '#03', 'Homework', '#2', 'Due', 'Date:', '2021년', '10월', 
'08일,', '23시', '59분', '06', '10월', '01일(금)/05일(화)', '06.', '문자열', '자료형의', '메소드와', '포맷팅', '03.', '고급', 
'리스트', '기능', '-', 'II', 'Lecture', 'Note', '#03', '&nbsp;', '07', '10월', '08일(금)/12일(화)', '07.', '파이썬의', '조건문', 
'04.', '지름길,', '커맨드', '라인', '그리고', '패키지', '-', 'I', 'Lecture', 'Note', '#04', 'Homework', '#3', 'Due', 'Date:', 
'2021년', '10월', '22일,', '23시', '59분', '08', '10월', '15일(금)/19일(화)', '08.', '파이썬의', '반복문', '04.', '지름길,', '커맨드', 
'라인', '그리고', '패키지', '-', 'II', 'Lecture', 'Note', '#04', '&nbsp;', '09', '10월', '22일(금)', '09.', '파이썬의', '파일', 
'입출력', '05.', '정밀하게', '텍스트', '포매팅하기', 'Lecture', 'Note', '#05', '&nbsp;', '10', '10월', '26일(화)', '중간', '고사', 
'&nbsp;', '&nbsp;', '11', '10월', '29일(금)/11월', '02일(화)', '10.', '파이썬의', '함수', '08.', '텍스트와', '바이너리', '파일', 
'Lecture', 'Note', '#08', '&nbsp;', '12', '11월', '05일(금)/09일(화)', '11.', '파이썬', '함수의', '활용과', '람다', '함수', '09.',
'클래스와', '매직', '메소드', 'Lecture', 'Note', '#09', 'Homework', '#4', 'Due', 'Date:', '2021년', '11월', '19일,', '23시', '
59분', '13', '11월', '12일(금)/16일(화)', '12.', '파이썬의', '모듈', '11.', 'Random과', 'Math', '패키지', 'Lecture', 'Note', '#11',
'&nbsp;', '14', '11월', '19일(금)/23일(화)', '13.', '파이썬', '외부', '모듈의', '활용', '12.', '넘파이', '패키지', 'Lecture', 
'Note', '#12', '&nbsp;', '15', '11월', '26일(금)/30일(화)', '14.', '파이썬의', '클래스', '13.', '넘파이', '고급', '사용법', 'Lecture',
'Note', '#13', 'Homework', '#5', 'Due', 'Date:', '2021년', '12월', '10일,', '23시', '59분', '16', '12월', '03일(금)/07일(화)',
'15.', '파이썬', '클래스의', '활용', '14.', '여러', '모듈과', 'RPN', '예시', 'Lecture', 'Note', '#14', '&nbsp;', '17', '12월', 
'10일(금)/14일(화)', '16.', '파이썬의', '예외', '처리', '15.', '인터넷에서', '금융', '데이터', '가져오기', 'Lecture', 'Note', '#15',
'&nbsp;', '18', '12월', '17일(금)', '기말', '고사', '&nbsp;', '&nbsp;', '2.', 'Course', 'Information', 'Lecturer:', '한연희', '교수',
'(Rm.', '2공학관', '423호,', 'Email:', 'yhhan@koreatech.ac.kr)', 'Classes:', '1분반:', '화요일', '(11:00', '~', '13:00,', '화03A', '~',
'04B),', '금요일', '(09:00', '~', '11:00,', '금01A', '~', '02B)', '2분반:', '화요일', '(09:00', '~', '11:00,', '화01A', '~', '02B),', 
'금요일', '(11:00', '~', '13:00,', '금03A', '~', '04B)', 'Lecture', 'Room:', '409호', '수업조교(TA):', '지창훈', '석사과정', '(Email:', 
'koir5660@koreatech.ac.kr)', '최요한', '석사과정', '(Email:', 'yoweif@koreatech.ac.kr)', 'Prerequisites:', '컴퓨터', '활용과', '이해', 
'Course', 'Board(숙제', '제출', '사이트):', 'http://el.koreatech.ac.kr', '[숙제', '제출', '방법]', '1)', 'jupyter', 'notebook', 
'환경에서', '각', '숙제별로', 'ipynb', '파일', '생성', '-', 'jupyter', 'notebook', '사용법', '-1', '-', 'jupyter', 'notebook', '사용법',
'-2', '-', 'Python', '3.6', '버전으로', '코딩을', '해야', '함.', '2)', 'ipynb', '파일', '내에', '코드를', '작성하고', '작성한', 
'코드', '설명시에', 'Markdown', '문법으로', '입력해야', '함', '-', 'Markdown', '사용법은', '각자', '익힐', '것', '-', 'Markdown', 
'사용법', '-', 'Markdown', 'Tutorial', '-', 'Markdown', 'Online', 'Editor', '3)', '생성한', 'ipynb', '파일에', '대해', '자신만의', 
'방법을', '사용하여', '온라인상', 'URL을', '생성', '-', '예', '1.', 'Github', '사이트로', '업로드', '후', 'URL', '얻기', '-', '예', 
'2.', 'Drobbox', '폴더로', '업로드', '후', 'URL', '얻기', '4)', '다음', '사이트에', '해당', 'URL을', '입력', '-', 
'http://nbviewer.jupyter.org', '-', '위', 'nbviewer', '사이트를', '통하여', '보여지는', '자신의', '숙제를', '확인하고', '해당', 
'nbviewer', 'URL을', '숙제', '게시판', '본문에', '글쓰기로', '등록', '-', '따라서,', '숙제', '등록', 'URL은', '반드시', 
'http://nbviewer.jupyter.org/', '로', '시작해야', '함.', '-', '숙제', '등록', 'URL', '예:', 
'http://nbviewer.jupyter.org/urls/dl.dropbox.com/s/t9nmklgjkp7w4ok/kmeans.ipynb', '3.', 'Reference', '#', '온라인', '강의', '교재', 
'파이썬', '프로그래밍(2019년),', '한국기술교육대학교', '온라인', '평생교육원', 'STEP', '#', '오프라인/Zoom', '실시간', '강의', '교재',
'(구매', '필수)', '주교재:', '브라이언', '오버랜드,', '존', '베넷', '저/조인석', '역,', '파이썬', '스킬업,', '길벗,', '2021', '원서:',
'Brian', 'Overland', 'and', 'John', 'Bennett,', 'Supercharged', 'Python:', 'Take', 'Your', 'Code', 'to', 'the', 'Next', 'Level,', 
'Addison-Wesley,', '2019', 'Click', '4.', 'Logistics', 'Attendance', '–', 'one', 'class', 'absence', 'will', 'result', 'in', 'the', 
'deduction', 'of', 'two', 'points', 'out', 'of', '100', 'points.', 'Five', 'absences', 'will', 'not', 'result', 'in', 'ten', 'points', 
'deduction,', 'but', '“failure”', '(i.e.,', 'grade', '‘F’)', 'in', 'this', 'course.', 'Exam', '–', 'there', 'will', 'be', 
'midterm', 'exam', 'and', 'final', 'exam', 'for', 'the', 'evaluation', 'of', 'the', 'knowledge', 'learned', 'from', 'the', 'class.', 
'Homework', '–', 'much', 'intensive', 'homework', 'will', 'be', 'set.', 'Any', 'cheating', '(or', 'copying)', 'will', 'result', 'in',
'grade', '‘F’.', '5.', 'Evaluation', 'Attendance', '(10%),', 'Quiz', '(10%),', 'Homework', '(20%),', 'Midterm', 'exam', '(30%),',
'Final', 'exam', '(30%)', 'Laboratory', 'Partners', '한국기술교육대학교', 'KOREATECH', '컴퓨터공학부', 'KOREATECH', '첨단기술연구소',
'KOREATECH', '다산정보관', '한국연구재단', '구글학술검색', 'Copyright', '&copy;', '2020', 'Laboratory', 'of', 'Intelligent', 'Networks',
'All', 'Rights', 'Reserved.', 'Copyright', '&copy;', '2020', 'Laboratory', 'of', 'Intelligent', 'Networks', 'All', 'Rights', 
'Reserved.', 'var', 'baseUrl', '=', '"index.html";', 'var', 'acc', '=', 'document.getElementsByClassName("accordion");', 'for', 
'(var', 'i', '=', '0;', 'i']'''
# Out:
# ['한국기술교육대학교', 'LINK', '연구실', '위치', 'LINK@KOREATECH', 'About', 'Introduction', 'Location', 'Members', 'Professor', 'Current', 'Students/Members', 'Alumni', 'Publications', 'Papers', 'Patents', 'Standards', 'Research', 'Research', 'Areas', 'Projects', 'Courses', 'Courses&nbsp;(Since', '2021)', 'Old', 'Courses&nbsp;(Until', '2020)', 'Activity', 'News', 'Invited', 'Talks', 'Lab.', 'Seminar', 'Zoom', 'Meeting', 'Awards', 'Album', 'About', 'Introduction', 'Location', 'Members', 'Professor', 'Current', 'Students/Members', 'Alumni', 'Publications', 'Papers', 'Patents', 'Standards', 'Books', 'Research', 'Research', 'Areas', 'Projects', 'Courses', 'Courses&nbsp;(Since', '2021)', 'Old', 'Courses&nbsp;(Until', '2020)', 'Activity', 'News', 'Invited', 'Talks', 'Lab.', 'Seminar', 'Awards', 'Album', 'Script', 'Programming', 'Home', 'Course', '2021', 'Fall', 'Script', 'Programming', 'Script', 'Programming', '(스크립트', '프로그래밍,', 'Fall', 'Semester,', '2021', '–', 'CSE221)', '“Student-professor', 'relatio
# ...

# %%
print(source)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" lang=""> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9" lang=""> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en">
#
# <!-- Mirrored from dmqm.korea.ac.kr/ by HTTrack Website Copier/3.x [XR&CO'2014], Sat, 04 Apr 2020 08:31:27 GMT -->
# <!-- Added by HTTrack -->
# <meta http-equiv="content-type" content="text/html;charset=UTF-8"/><!-- /Added by HTTrack -->
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link rel="apple-touch-icon" sizes="57x57" href="/static/assets/images/favicon/apple-icon-57x57.png">
#     <link rel="apple-touch-icon" sizes="60x60" href="/static/assets/images/favicon/apple-icon-60x60.png">
# ...

# %% [markdown]
# -----

# %% [markdown]
# ### 소감

# %% [markdown]
# 오늘은 과제를 수행하는데 너무 오래걸렸습니다 ㅜㅜ.. 뭔가 파이썬은 다른 언어들과 다르게 경우의 수가 많아 헷갈릴때마다 실험을 하면서 하는 경우가 많았습니다. 이런 경우가 생기지 않도록 이론 공부를 더 열심히 해야겠다는 생각을 하게 되었습니다. 그리고, 마지막 문제를 해결하는데 겉으로 보기에는 와.. 너무 어렵겠다.. 라는 생각을 많이 했는데, 직접 접하고 나니 머야? 너무 쉽잖아? 라는 생각을 하게 되었습니다. 이상하게.. 앞의 문제들보다 쉽게 풀어졌습니다. 풀고나서는 내가 푼것이 맞는건가? 라는 생각을 하게 되는.. 제가 선택한 URL이 쉬운것들인지는 모르겠지만 잘 해결되서 다행이라고 생각하고 있습니다. 이번 과제를 수행하면서 신기한 부분과 어려운 부분도 있었지만 잘 해결한 나 자신이 뿌듯하게 느껴집니다. 강의 열심히 따라가겠습니다. 감사합니다.
#
# -----
